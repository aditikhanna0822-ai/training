# %% [markdown]
# <a href="https://colab.research.google.com/github/aditikhanna0822-ai/training/blob/main/training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
passage=input("enter passage:")
words=passage.split()
dict={}
for word in words:
    if word in dict:
        dict[word]+=1
    else:
        dict[word]=1
top5=sorted(dict.items(),key=lambda x:x[1],reverse=True)[:5]
print("top 5 frequent words are as follows:")
for k,v in top5:
    print(k," ",v)
# Out:
# enter passage:hello hello aditi aditi bye
# top 5 frequent words are as follows:
# hello   2
# aditi   2
# bye   1

# %%
cart=[]
prices={}
categories=set()
n=int(input("enter the no of items:"))
for i in range(n):
      item=input("enter item ")
      price=int(input("enter price "))
      category=input("enter categoy ")
      cart.append(item)
      prices[item]=price
      categories.add(category)
  #add item
a=input("enterr item name to add")
b=int(input("enter price to add"))
c=input("enter category")
categories.add(c)
cart.append(a)
prices[a]=b
# remove
r=input("add item to remove:")
if r in cart:
      cart.remove(r)
      del prices[r]
print("cart items aree:", cart)
print("uniuque category are:",categories)
print("iem prices are")
for i,k in prices.items():
      print(i,":",k)
bill=sum(prices.values())
print("total bill is:",bill)
# Out:
# enter the no of items:2
# enter item banana
# enter price 30
# enter categoy fruit
# enter item litchi
# enter price 20
# enter categoy fruit
# enterr item name to addpen
# enter price to add20
# enter categorystationery
# add item to remove:litchi
# cart items aree: ['banana', 'pen']
# uniuque category are: {'stationery', 'fruit'}
# iem prices are
# banana : 30
# pen : 20
# total bill is: 50

# %%
#contact book
contacts = {
    "Aditi": "9876543210",
    "Ritika": "9876543211",
    "Annu": "9876543212"
}

phone_set = set(contacts.values())

# Add Contact
name = "Shia"
phone = "9876543213"

if phone in phone_set:
    print("Duplicate phone number")
else:
    contacts[name] = phone
    phone_set.add(phone)
# Search Contact
search_name = "Aditi"

if search_name in contacts:
    print("Found:", contacts[search_name])
else:
    print("Not Found")

# Update Contact
contacts["Annu"] = "9999999999"
phone_set.add("9999999999")

# Delete Contact
del contacts["Ritika"]

print("Final Contacts:")
print(contacts)
# Out:
# Found: 9876543210
# Final Contacts:
# {'Aditi': '9876543210', 'Annu': '9999999999', 'Shia': '9876543213'}

# %%
# q 4 student
students = {}

n = int(input("Enter number of students: "))

for i in range(n):
    name = input("Enter student name: ")
    marks = int(input("Enter marks: "))
    students[name] = marks
average = sum(students.values()) / len(students)
topper = max(students, key=students.get)
grades = []
for mark in students.values():
    if mark >= 90:
        grades.append("A")
    elif mark >= 80:
        grades.append("B")
    elif mark >= 70:
        grades.append("C")
    else:
        grades.append("D")
print("Student Marks:", students)
print("Average Marks:", average)
print("Topper:", topper, "-", students[topper])
print("Grades:", grades)
# Out:
# Enter number of students: 3
# Enter student name: aditi
# Enter marks: 90
# Enter student name: riya
# Enter marks: 88
# Enter student name: naina
# Enter marks: 87
#
# Student Marks: {'aditi': 90, 'riya': 88, 'naina': 87}
# Average Marks: 88.33333333333333
# Topper: aditi - 90
# Grades: ['A', 'B', 'B']

# %%
# q 5
import random
number = random.randint(1, 100)
attempts = 0
print("Guess a number between 1 and 100")
while True:
    guess = int(input("Enter your guess: "))
    attempts += 1
    if guess > number:
        print("Too High!")
    elif guess < number:
        print("Too Low!")
    else:
        print("Correct!")
        print("Attempts:", attempts)
        break
# Out:
# Guess a number between 1 and 100
# Enter your guess: 80
# Too Low!
# Enter your guess: 97
# Too High!
# Enter your guess: 90
# Too Low!
# Enter your guess: 94
# Correct!
# Attempts: 4

# %%
# q 6
pin = "1234"
balance = 10000
entered_pin = input("Enter PIN: ")
if entered_pin == pin:
    while True:
        print("\n1. Check Balance")
        print("2. Deposit")
        print("3. Withdraw")
        print("4. Exit")
        choice = input("Enter choice: ")
        if choice == "1":
            print("Balance =", balance)
        elif choice == "2":
            amount = float(input("Enter deposit amount: "))
            balance += amount
            print("Updated Balance =", balance)
        elif choice == "3":
            amount = float(input("Enter withdrawal amount: "))
            if amount <= balance:
                balance -= amount
                print("Updated Balance =", balance)
            else:
                print("Insufficient Balance")
        elif choice == "4":
            print("Thank You!")
            break
        else:
            print("Invalid Choice")

else:
    print("Incorrect PIN")
# Out:
# Enter PIN: 1234
#
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Enter choice: 1
# Balance = 10000
#
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Enter choice: 2
# Enter deposit amount: 500
# Updated Balance = 10500.0
#
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Enter choice: 3
# Enter withdrawal amount: 400
# Updated Balance = 10100.0
#
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Enter choice: 4
# Thank You!

# %%
#q 7
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
print("1. Addition")
print("2. Subtraction")
print("3. Multiplication")
print("4. Division")
choice = input("Enter choice: ")
if choice == "1":
    print("Result =", num1 + num2)
elif choice == "2":
    print("Result =", num1 - num2)
elif choice == "3":
    print("Result =", num1 * num2)
elif choice == "4":
    if num2 != 0:
        print("Result =", num1 / num2)
    else:
        print("Division by zero is not allowed")
else:
    print("Invalid Choice")
# Out:
# Enter first number: 1
# Enter second number: 2
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# Enter choice: 3
# Result = 2.0

# %%
# q4
text = input("Enter a paragraph: ")
words = text.split()
word_count = len(words)
longest_word = ""
for word in words:
    if len(word) > len(longest_word):
        longest_word = word
print("Total Words:", word_count)
print("Longest Word:", longest_word)
print("Length of Longest Word:", len(longest_word))
# Out:
# Enter a paragraph: hello how is the weather today
# Total Words: 6
# Longest Word: weather
# Length of Longest Word: 7

# %%
import math
